# %%
from sklearn.model_selection import train_test_split, KFold
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
import numpy as np
import pandas as pd
import statistics
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import json
import requests
import math
# %matplotlib inline


plt.style.use('ggplot')
# Out:
# c:\Users\Morgan\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
public_trans_full16 = pd.read_csv('../data/2016_metrics.csv')
public_trans_full17 = pd.read_csv('../data/2017_metrics.csv')
public_trans_full18 = pd.read_csv('../data/2018_metrics.csv')
public_trans_full19 = pd.read_csv('../data/2019_metrics.csv')
public_trans_full20 = pd.read_csv('../data/2020_metrics.csv')
public_trans_full20.head(3)
# Out:
#                       Agency      City State Legacy NTD ID NTD ID  \
# 0  MTA New York City Transit  Brooklyn    NY          2008  20008
# 1  MTA New York City Transit  Brooklyn    NY          2008  20008
# 2  MTA New York City Transit  Brooklyn    NY          2008  20008
#
#                                    Organization Type  Reporter Type  \
# 0  Subsidiary Unit of a Transit Agency, Reporting...  Full Reporter
# 1  Subsidiary Unit of a Transit Agency, Reporting...  Full Reporter
# 2  Subsidiary Unit of a Transit Agency, Reporting...  Full Reporter
#
#   Primary UZA\n Population Agency VOMS Mode  ... Passenger Miles Questionable  \
# 0              18,351,295       10,427   HR  ...                          NaN
# 1              18,351,295       10,427   CB  ...                          NaN
# 2              18,351,295       10,427   MB  ...                            W
#
#   Vehicle Revenue Miles  Vehicle Revenue Miles Questionable  \
# 0          324,782,077                                  NaN
# 1            8,690,192                                  NaN
# 2           80,118,986                                  NaN
#
#   Any data questionable? Unnamed: 39  Unnamed: 40  Unnamed: 41  \
# 0                     No         NaN          NaN          NaN
# 1                     No         NaN          NaN          NaN
# 2                    Yes         NaN          2.0          NaN
#
#                              1 Unnamed: 43  Unnamed: 44
# 0  Hide questionable data tags         NaN          NaN
# 1  Show questionable data tags         NaN          NaN
# 2                            1         NaN          2.0
#
# [3 rows x 45 columns]

# %%
# New York Crime Rate
fig = px.choropleth(county_trans_miles_map, geojson= ny_geojson, color='Passenger Miles', locations='Three Digit County Code')
fig.update_geos(fitbounds="locations", visible=False)
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Morgan\daimil10\final_pro_two\notebooks\2016-2020_public_trans_real.ipynb Cell 4 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Morgan/daimil10/final_pro_two/notebooks/2016-2020_public_trans_real.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> # New York Crime Rate
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Morgan/daimil10/final_pro_two/notebooks/2016-2020_public_trans_real.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> fig = px.choropleth(county_trans_miles_map, geojson= ny_geojson, color='Passenger Miles', locations='Three Digit County Code')
#       <a href='vscode-notebook-cell:/c%3A/Users/Morgan/daimil10/final_pro_two/notebooks/2016-2020_public_trans_real.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> fig.update_geos(fitbounds="locations", visible=False)
#       <a href='vscode-notebook-cell:/c%3A/Users/Morgan/daimil10/final_pro_two/notebooks/2016-2020_public_trans_real.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
#
# NameError: name 'county_trans_miles_map' is not defined
